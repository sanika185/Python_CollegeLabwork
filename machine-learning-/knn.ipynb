# %%
import pandas as pd
import numpy

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
accuracy = knn.score(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 81.40%

# %%
def predict_user_input():
    print("\nPlease input the following features for prediction:")

    # Assuming this example is for the iris dataset, which has 4 features (adjust based on your dataset)
    try:
        S1_RI = float(input("Enter for RI: "))
        S1_Na= float(input("Enter for Na : "))
        S1_Mg = float(input("Enter for Mg: "))
        S1_Al = float(input("Enter for Al: "))
        S1_Si = float(input("Enter for Si: "))
        S1_K= float(input("Enter for K: "))
        S1_Ca = float(input("Enter for Ca: "))
        S1_Ba = float(input("Enter for Ba: "))
        S1_Fe = float(input("Enter for Fe:"))

        # Create a feature vector from the user input
        user_data = [[S1_RI, S1_Na, S1_Mg, S1_Al ,S1_Si , S1_K, S1_Ca ,S1_Ba , S1_Fe ]]

        # Scale the user input data
        user_data_scaled = scaler.transform(user_data)

        # Predict the class using the trained KNN model
        prediction = knn.predict(user_data_scaled)
        predicted_class = df.Type[prediction][0]

        print(f"\nPredicted Type No: {predicted_class}")
        
    except ValueError:
        print("Invalid input! Please enter numeric values only.")
  

predict_user_input()
# Out:
# Please input the following features for prediction:
# c:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3716\1838342802.py in ?()
#      28     except ValueError:
#      29         print("Invalid input! Please enter numeric values only.")
#      30
#      31
# ---> 32 predict_user_input()
#
# ~\AppData\Local\Temp\ipykernel_3716\1838342802.py in ?()
#      24         predicted_class = df.target_names[prediction][0]
#      25
#      26         print(f"\nPredicted Type No: {predicted_class}")
#      27
# ---> 28     except ValueError:
#      29         print("Invalid input! Please enter numeric values only.")
#
# ...
